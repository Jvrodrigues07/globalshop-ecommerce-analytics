# %%
from pathlib import Path
import pandas as pd

# achar a pasta raiz automaticamente
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "data").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"

# carregar tabela
orders = pd.read_csv(DATA_DIR / "olist_orders_dataset.csv")

orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
payments = pd.read_csv(DATA_DIR / "olist_order_payments_dataset.csv")
customers = pd.read_csv(DATA_DIR / "olist_customers_dataset.csv")
items = pd.read_csv(DATA_DIR / "olist_order_items_dataset.csv")
products = pd.read_csv(DATA_DIR / "olist_products_dataset.csv")

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])
orders["order_delivered_customer_date"] = pd.to_datetime(orders["order_delivered_customer_date"])

# %%
orders.shape, payments.shape, customers.shape, items.shape, products.shape
# Out:
# ((99441, 8), (103886, 5), (99441, 5), (112650, 7), (32951, 9))

# %%
display(orders.head())
display(payments.head())
display(items.head())
display(customers.head())
display(products.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders[["order_purchase_timestamp", "order_delivered_customer_date"]].dtypes
# Out:
# order_purchase_timestamp         datetime64[us]
# order_delivered_customer_date    datetime64[us]
# dtype: object

# %%
orders_delivered = orders[orders["order_status"] == "delivered"].copy()
orders_delivered.shape
# Out:
# (96478, 8)

# %%
pay_by_order = (payments
    .groupby("order_id", as_index=False)["payment_value"]
    .sum()
    .rename(columns={"payment_value": "revenue"})
)
pay_by_order.head()
# Out:
#                            order_id  revenue
# 0  00010242fe8c5a6d1ba2dd792cb16214    72.19
# 1  00018f77f2f0320c557190d7a144bdd3   259.83
# 2  000229ec398224ef6ca0657da4fc703e   216.87
# 3  00024acbcdf0a6daa1e931b038114c75    25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9   218.04

# %%
rev_base = orders_delivered.merge(pay_by_order, on="order_id", how="left")

rev_base["month"] = rev_base["order_purchase_timestamp"].dt.to_period("M").astype(str)

rev_monthly = (rev_base
    .groupby("month", as_index=False)["revenue"]
    .sum()
    .sort_values("month")
)

rev_monthly.head(), rev_monthly.tail()
# Out:
# (     month    revenue
#  0  2016-09       0.00
#  1  2016-10   46566.71
#  2  2016-12      19.62
#  3  2017-01  127545.67
#  4  2017-02  271298.65,
#        month     revenue
#  18  2018-04  1132933.95
#  19  2018-05  1128836.69
#  20  2018-06  1012090.68
#  21  2018-07  1027903.86
#  22  2018-08   985414.28)

# %%
rev_base = orders_delivered.merge(pay_by_order, on="order_id", how="left")
rev_base.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(rev_monthly["month"], rev_monthly["revenue"])
plt.xticks(rotation=45)
plt.title("Revenue Over Time (Monthly)")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.tight_layout()
plt.show()

# %%
rev_monthly.to_csv("../../docs/revenue_monthly.csv", index=False)

# %% [markdown]
# # -----------------------------
# # Orders Over Time
# # -----------------------------

# %%
orders_monthly = (orders_delivered
    .assign(month=orders_delivered["order_purchase_timestamp"].dt.to_period("M").astype(str))
    .groupby("month", as_index=False)["order_id"]
    .count()
    .rename(columns={"order_id": "orders"})
    .sort_values("month")
)

orders_monthly.head()
# Out:
#      month  orders
# 0  2016-09       1
# 1  2016-10     265
# 2  2016-12       1
# 3  2017-01     750
# 4  2017-02    1653

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(orders_monthly["month"], orders_monthly["orders"])
plt.xticks(rotation=45)
plt.title("Orders Over Time (Monthly)")
plt.xlabel("Month")
plt.ylabel("Orders")
plt.tight_layout()
plt.show()

# %%
orders_monthly.to_csv("../../docs/orders_monthly.csv", index=False)
